# %%
# python -m venv .venv
# source .venv/bin/activate  # On Windows, use `.venv\Scripts\activate`
# %pip install langgraph
# Out:
# Collecting langgraph
#   Downloading langgraph-1.0.5-py3-none-any.whl.metadata (7.4 kB)
# Collecting langchain-core>=0.1 (from langgraph)
#   Downloading langchain_core-1.2.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph)
#   Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph)
#   Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph)
#   Downloading langgraph_sdk-0.3.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/suma/Training/.venv/lib/python3.13/site-packages (from langgraph) (2.12.4)
# Collecting xxhash>=3.5.0 (from langgraph)
#   Using cached xxhash-3.6.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph)
#   Downloading ormsgpack-1.12.1-cp313-cp313-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (3.2 kB)
# Requirement already satisfied: httpx>=0.25.2 in /Users/suma/Training/.venv/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/suma/Training/.venv/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.4)
# Requirement already satisfied: anyio in /Users/suma/Training/.venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.11.0)
# Requirement already satisfied: certifi in /Users/suma/Training/.venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/suma/Training/.venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in /Users/suma/Training/.venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/suma/Training/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core>=0.1->langgraph)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core>=0.1->langgraph)
#   Downloading langsmith-0.4.59-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/suma/Training/.venv/lib/python3.13/site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/suma/Training/.venv/lib/python3.13/site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core>=0.1->langgraph)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/suma/Training/.venv/lib/python3.13/site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core>=0.1->langgraph)
#   Using cached uuid_utils-0.12.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (1.1 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in /Users/suma/Training/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.5)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached zstandard-0.25.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/suma/Training/.venv/lib/python3.13/site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/suma/Training/.venv/lib/python3.13/site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/suma/Training/.venv/lib/python3.13/site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/suma/Training/.venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/suma/Training/.venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/suma/Training/.venv/lib/python3.13/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.3.1)
# Downloading langgraph-1.0.5-py3-none-any.whl (157 kB)
# Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.3.0-py3-none-any.whl (66 kB)
# Downloading langchain_core-1.2.0-py3-none-any.whl (475 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.4.59-py3-none-any.whl (413 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached uuid_utils-0.12.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (603 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading ormsgpack-1.12.1-cp313-cp313-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (376 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached xxhash-3.6.0-cp313-cp313-macosx_11_0_arm64.whl (30 kB)
# Using cached zstandard-0.25.0-cp313-cp313-macosx_11_0_arm64.whl (640 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, tenacity, ormsgpack, jsonpointer, requests-toolbelt, jsonpatch, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/14 [langgraph]14 [langgraph-prebuilt]
# Successfully installed jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-1.2.0 langgraph-1.0.5 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.5 langgraph-sdk-0.3.0 langsmith-0.4.59 ormsgpack-1.12.1 requests-toolbelt-1.0.0 tenacity-9.1.2 uuid-utils-0.12.0 xxhash-3.6.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langgraph.graph import StateGraph, START, END

# %%
def node_a_agent(dict):
    # Simulate some processing
    # Do something useful here
    print("Agent A is running")
    return {}

def node_b_agent(dict):
    # Simulate some processing
    # Do something useful here
    print("Agent B is running")
    return {}

builder = StateGraph(dict)
builder.add_node("Agent_A", node_a_agent)
builder.add_node("Agent_B", node_b_agent)

builder.add_edge(START, "Agent_A")
builder.add_edge("Agent_A", "Agent_B")
builder.add_edge("Agent_B", END)


graph = builder.compile()

# %%
# %pip install grandalf
# Out:
# Collecting grandalf
#   Using cached grandalf-0.8-py3-none-any.whl.metadata (1.7 kB)
# Collecting pyparsing (from grandalf)
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Using cached grandalf-0.8-py3-none-any.whl (41 kB)
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Installing collected packages: pyparsing, grandalf
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [grandalf]
# Successfully installed grandalf-0.8 pyparsing-3.2.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# --- Display as ASCII ---
print(graph.get_graph().draw_ascii())
# Out:
# +-----------+
# | __start__ |
# +-----------+
#       *
#       *
#       *
#  +---------+
#  | Agent_A |
#  +---------+
#       *
#       *
#       *
#  +---------+
#  | Agent_B |
#  +---------+
#       *
#       *
#       *
#  +---------+
#  | __end__ |
#  +---------+
