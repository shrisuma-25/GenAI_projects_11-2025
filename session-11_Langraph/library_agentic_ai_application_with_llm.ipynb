# %%
from typing import TypedDict, Optional
from langgraph.graph import StateGraph, START, END

from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv(override=True)
my_api_key = os.getenv("OPENAI_API_KEY")
# print (f'Key is {my_api_key}')


client = OpenAI(api_key=my_api_key)


# --- Shared State ---
class LibraryState(TypedDict):
    question: Optional[str]
    faq_flag: Optional[bool]
    faq_answer: Optional[str]
    checkout_flag: Optional[bool]
    checkout_answer: Optional[str]
    final_answer: Optional[str]

def ClassifierAgent(state: LibraryState):
    print(f"ClassifierAgent Initial state: {state}")

    question = state["question"]

    messages = [
        {
            "role": "system",
            "content": (
                "You are a classifier agent in a library system.\n"
                "Determine whether the question involves:\n"
                "1. Library FAQs (hours, rules, membership)\n"
                "2. Book availability or checkout\n\n"
                "Return ONLY valid JSON:\n"
                "{\n"
                '  "faq_flag": true | false,\n'
                '  "checkout_flag": true | false\n'
                "}"
            )
        },
        {"role": "user", "content": question}
    ]

    response = client.chat.completions.create(
        model="gpt-5-nano",
        messages=messages,
    )

    import json
    parsed = json.loads(response.choices[0].message.content)

    return {
        "faq_flag": bool(parsed.get("faq_flag", False)),
        "checkout_flag": bool(parsed.get("checkout_flag", False)),
    }
def FAQAgent(state: LibraryState):
    print(f"FAQAgent state: {state}")

    if not state.get("faq_flag"):
        return {"faq_answer": None}

    messages = [
        {"role": "system", "content": "You answer library FAQ questions."},
        {"role": "user", "content": state["question"]}
    ]

    response = client.chat.completions.create(
        model="gpt-5-nano",
        messages=messages,
    )

    return {
        "faq_answer": response.choices[0].message.content
    }



def CheckoutAgent(state: LibraryState):
    print(f"CheckoutAgent state: {state}")

    if not state.get("checkout_flag"):
        return {"checkout_answer": None}

    messages = [
        {"role": "system", "content": "You answer questions about book availability and checkout."},
        {"role": "user", "content": state["question"]}
    ]

    response = client.chat.completions.create(
        model="gpt-5-nano",
        messages=messages,
    )

    return {
        "checkout_answer": response.choices[0].message.content
    }
def ResponseAgent(state: LibraryState):
    print(f"ResponseAgent state: {state}")

    faq = state.get("faq_answer")
    checkout = state.get("checkout_answer")

    parts = []
    if faq:
        parts.append(f"FAQ Information:\n{faq}")
    if checkout:
        parts.append(f"Checkout Information:\n{checkout}")

    combined_context = "\n\n".join(parts)

    messages = [
        {
            "role": "system",
            "content": "Combine the information into a helpful response."
        },
        {
            "role": "user",
            "content": f"Question: {state['question']}\n\n{combined_context}"
        }
    ]

    response = client.chat.completions.create(
        model="gpt-5-nano",
        messages=messages,
    )

    return {
        "final_answer": response.choices[0].message.content
    }
# --- Build the Graph ---
builder = StateGraph(LibraryState)
builder.add_node("ClassifierAgent", ClassifierAgent)
builder.add_node("FAQAgent", FAQAgent)
builder.add_node("CheckoutAgent", CheckoutAgent)
builder.add_node("ResponseAgent", ResponseAgent)

builder.add_edge(START, "ClassifierAgent")
builder.add_edge("ClassifierAgent", "FAQAgent")
builder.add_edge("ClassifierAgent", "CheckoutAgent")
builder.add_edge("FAQAgent", "ResponseAgent")
builder.add_edge("CheckoutAgent", "ResponseAgent")
builder.add_edge("ResponseAgent", END)

graph = builder.compile()

# %%
result = graph.invoke({"question": "Is The new best seller available? When does library open?"})
print("\n--- Final Answer ---")
print(result["final_answer"])
# Out:
# ClassifierAgent Initial state: {'question': 'Is The new best seller available? When does library open?'}
# CheckoutAgent state: {'question': 'Is The new best seller available? When does library open?', 'faq_flag': True, 'checkout_flag': True}FAQAgent state: {'question': 'Is The new best seller available? When does library open?', 'faq_flag': True, 'checkout_flag': True}
#
# ResponseAgent state: {'question': 'Is The new best seller available? When does library open?', 'faq_flag': True, 'faq_answer': 'I can help with both, but I need a couple details:\n\n- Which library or branch are you asking about?\n- Do you have the exact title or author for the “new bestseller”?\n\nIf you want to proceed now:\n- Availability: I can check the library catalog for the title and tell you if a copy is available, on hold, or checked out. If it’s not available, you can usually place a hold to be notified when it’s back on the shelf.\n- Hours: Opening hours vary by branch and day. Tell me the library name or your city, and I’ll pull today’s hours and the coming week’s schedule. If you prefer, you can also check the library’s Hours page on their website or in the library app.\n\nShare the details and I’ll look it up for you.', 'checkout_flag': True, 'checkout_answer': 'I can help, but I need a couple details:\n\n- Which library or branch are you using?\n- Do you have the exact title or the author (“The new best seller” is a bit vague)?\n\nIf you just want to know how to check right now, you can do this:\n- Availability: Open your library’s online catalog, search by the exact title or author, and look at the item’s status. If it’s available, you can check it out or place a hold if it’s checked out.\n- Hours: Check the library’s Hours or Location page on their website, or call the desk. Hours can vary by branch and day, and may differ on holidays.\n\nIf you share the library name (and the exact title or author), I’ll look up the current status and the hours for that location.'}
#
# --- Final Answer ---
# I can help with both—availability and hours. I just need a couple details:
#
# What I need from you
# - Library or branch name (or your city if you don’t know the exact branch)
# - The exact title and/or the author of the “new bestseller” (the phrase alone is a bit vague)
#
# What happens next
# - Availability: I’ll look up the title in the catalog and tell you if a copy is available, on hold, or checked out. If it’s not available, I can guide you on placing a hold.
# - Hours: I’ll pull today’s hours and the coming week’s schedule for that branch. If you’d like, I can also point you to the library’s Hours page.
#
# If you’re not sure of the exact title/author, you can share keywords or the author’s name and I’ll try to locate the right book.
#
# Share the library name (or city) and the exact title or author and I’ll check everything for you.

# %%
# # --- Visualize ---
# print(graph.get_graph().draw_ascii())
# graph.get_graph().draw_png("images/agentic_ai_library.png")
# print("Graph saved as agentic_ai_library.png")

# %%
# --- Run ---
result = graph.invoke({"question": 
                       '''When does Cupertino library open? I would like to check out a book as 
                       well.'''})
print("\n--- Final Answer ---")
print(result["final_answer"])
# Out:
# ClassifierAgent Initial state: {'question': 'When does Cupertino library open? I would like to check out a book as \n                       well.'}
# CheckoutAgent state: {'question': 'When does Cupertino library open? I would like to check out a book as \n                       well.', 'faq_flag': True, 'checkout_flag': True}FAQAgent state: {'question': 'When does Cupertino library open? I would like to check out a book as \n                       well.', 'faq_flag': True, 'checkout_flag': True}
#
# ResponseAgent state: {'question': 'When does Cupertino library open? I would like to check out a book as \n                       well.', 'faq_flag': True, 'faq_answer': 'I can help with that.\n\n- Hours: Cupertino Library hours change by day. The quickest way to get today’s opening times is to check the official site or call the library. I can look up the current hours for you if you’d like.\n\n- Checking out a book: Here’s how to get started\n  - Get a library card: If you live in Santa Clara County, you can get a free library card. You’ll usually need a photo ID and proof of address. You can apply in person at the library or online if available.\n  - Use the catalog: With your card, you can search for titles and place holds on items you want. You can choose Cupertino Library as the pickup location.\n  - Check out: Bring your library card to the Circulation Desk during open hours to check out physical books. You can also borrow most items for a standard loan period and renew if there are no holds on the item.\n  - E-books and audiobooks: You can also borrow digital books via Libby/OverDrive using your library card.\n\nWould you like me to fetch the current hours for Cupertino Library now, or help you start a hold for a specific title? If you tell me your preferred day/time or a book you want, I can guide you step by step.', 'checkout_flag': True, 'checkout_answer': 'I can help with both, but opening times vary by day. Here’s how to get the exact hours and to check out a book:\n\n- Check hours: I can look up today’s Cupertino Library hours if you’d like (or you can check the Cupertino Library page on the Santa Clara County Library District site, or call them). Do you want me to fetch the current hours for today?\n\n- Check out a book:\n  - You’ll need a valid library card. Do you have one? If not, I can guide you through signing up.\n  - If you know the title or author, I can search the catalog for you, see if it’s available, and tell you how to place a hold if it’s checked out.\n  - You can check out in person at the library desk, or use self-checkout if available.\n  - You can also borrow eBooks/audiobooks through Libby/OverDrive if you prefer digital copies.\n\nTell me: do you want me to look up today’s hours, and what book are you hoping to borrow? If you already have a library card, share the card type (if you know it) and I’ll tailor the steps.'}
#
# --- Final Answer ---
# Happy to help. Here’s how it works:
#
# - Opening hours: Cupertino Library hours vary by day. I can fetch today’s hours for you if you’d like. Do you want me to look up today’s Cupertino Library hours now?
#
# - Checking out a book (physical):
#   - Do you have a Santa Clara County library card? If not, I can guide you through getting one.
#   - With a card, you can search the catalog for a title and place a hold (choose Cupertino Library as the pickup location).
#   - When the item is ready, go to the Circulation Desk during open hours or use self-checkout if available to check it out.
#
# - Checking out a book (digital):
#   - You can borrow eBooks/audiobooks via Libby/OverDrive with your library card.
#
# - How would you like to proceed?
#   - Want me to fetch today’s hours?
#   - Do you have a specific title and author in mind? If so, tell me the title (and author, if you have it) and whether you want a physical copy or an eBook, and I’ll guide you step by step or check availability. If you don’t have a card yet, I can help with the signup steps too.

# %%
result = graph.invoke({"question": "Is The Hobbit available? When does the library open"})
print("\n--- Final Answer ---")
print(result["final_answer"])
# Out:
# ClassifierAgent Initial state: {'question': 'Is The Hobbit available? When does the library open'}
# CheckoutAgent state: {'question': 'Is The Hobbit available? When does the library open', 'faq_flag': True, 'checkout_flag': True}FAQAgent state: {'question': 'Is The Hobbit available? When does the library open', 'faq_flag': True, 'checkout_flag': True}
#
# ResponseAgent state: {'question': 'Is The Hobbit available? When does the library open', 'faq_flag': True, 'faq_answer': 'I can help, but availability and hours depend on your library branch. Could you tell me:\n\n- Which library or city/branch are you using?\n- Do you want The Hobbit in a physical copy, or an eBook/audiobook?\n- Do you want today’s opening hours or the regular hours for the branch?\n\nIf you’d like, I can guide you to check in your library’s catalog and show you how to place a hold or find digital copies. For a quick check now, you can:\n- Search the library catalog for “The Hobbit” by J.R.R. Tolkien, then filter by format (physical, eBook, audiobook) and check the status.\n- Look for the “Hours” or “Locations” page of your branch to see today’s opening times.\n- If you want a digital copy, try Libby/OverDrive or Hoopla from your library’s digital services.', 'checkout_flag': True, 'checkout_answer': 'I can help with that. Which library or branch are you using? Do you want a physical copy or a digital version (ebook/audiobook)?\n\nIf you tell me the library name (and city, if needed), I’ll check:\n- Availability of The Hobbit at that branch\n- Today’s opening hours for that branch\n\nIf you’d prefer to check yourself, you can:\n- Search our catalog for “The Hobbit” and pick the edition you want\n- Check the item status (Available, Checked out, on Hold)\n- Look up the branch’s hours on the library’s website or call ahead\n\nWhat library should I look up for you?'}
#
# --- Final Answer ---
# I can help, but I need a bit more detail to give you a precise answer. Please tell me:
#
# - Which library or city/branch are you using?
# - Do you want The Hobbit in a physical copy, or an eBook/audiobook?
# - Do you want today’s opening hours or the branch’s regular hours?
#
# If you’d like, I can look it up for you. Just provide the library name (and city, if needed) and your format preference, and I’ll check:
# - Availability of The Hobbit at that branch
# - Today’s opening hours (or regular hours, if you prefer)
#
# If you want to check yourself now, you can:
# - Search the library catalog for “The Hobbit” by J.R.R. Tolkien, then filter by format (physical, eBook, audiobook) and check the status
# - Look for the “Hours” or “Locations” page of your branch to see today’s opening times
# - For a digital copy, try Libby/OverDrive or Hoopla using your library card
#
# What library should I look up for you?
