# %%
# %pip install openai pdfplumber python-docx pillow
from openai import OpenAI
import pdfplumber, docx, base64
client = OpenAI()
# Out:
# Requirement already satisfied: openai in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (2.8.0)
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.8-py3-none-any.whl.metadata (43 kB)
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting pillow
#   Using cached pillow-12.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Collecting pdfminer.six==20251107 (from pdfplumber)
#   Downloading pdfminer_six-20251107-py3-none-any.whl.metadata (4.2 kB)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-5.1.0-py3-none-macosx_11_0_arm64.whl.metadata (67 kB)
# Collecting charset-normalizer>=2.0.0 (from pdfminer.six==20251107->pdfplumber)
#   Using cached charset_normalizer-3.4.4-cp313-cp313-macosx_10_13_universal2.whl.metadata (37 kB)
# Collecting cryptography>=36.0.0 (from pdfminer.six==20251107->pdfplumber)
#   Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting lxml>=3.1.0 (from python-docx)
#   Downloading lxml-6.0.2-cp313-cp313-macosx_10_13_universal2.whl.metadata (3.6 kB)
# Collecting cffi>=2.0.0 (from cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber)
#   Downloading cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Downloading pdfplumber-0.11.8-py3-none-any.whl (60 kB)
# Downloading pdfminer_six-20251107-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 35.5 MB/s  0:00:00
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
# Using cached pillow-12.0.0-cp313-cp313-macosx_11_0_arm64.whl (4.7 MB)
# Using cached charset_normalizer-3.4.4-cp313-cp313-macosx_10_13_universal2.whl (208 kB)
# Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 41.7 MB/s  0:00:00
# Downloading cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl (181 kB)
# Downloading lxml-6.0.2-cp313-cp313-macosx_10_13_universal2.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 43.1 MB/s  0:00:00
# Downloading pypdfium2-5.1.0-py3-none-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 39.5 MB/s  0:00:00
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Installing collected packages: pypdfium2, pycparser, pillow, lxml, charset-normalizer, python-docx, cffi, cryptography, pdfminer.six, pdfplumber
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [pdfplumber]0 [pdfplumber]y]
# Successfully installed cffi-2.0.0 charset-normalizer-3.4.4 cryptography-46.0.3 lxml-6.0.2 pdfminer.six-20251107 pdfplumber-0.11.8 pillow-12.0.0 pycparser-2.23 pypdfium2-5.1.0 python-docx-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Extract Info from pdf
# ###### Reads text with pdfplumber and sends to GPT-5_nano for summarization

# %%
pdf_path = "data/California_Employment_Offer_Letter.pdf"  

def extract_text_from_pdf(path):
    text = ""
    with pdfplumber.open(path) as pdf:
        for page in pdf.pages:
            t = page.extract_text()
            if t:
                text += t + "\n"
    return text.strip()

pdf_text = extract_text_from_pdf(pdf_path)
pdf_text
# Out:
# 'EMPLOYMENT OFFER LETTER (CALIFORNIA)\nAcme Corporation\n1234 Market Street\nSan Francisco, CA 94105\nApril 1, 2023\nPrivate & Confidential\nJane Doe\n567 Oak Avenue\nSan Jose, CA 95112\nDear Jane,\nWe are delighted to extend to you an offer of employment with Acme Corporation (“Company”).\nThis letter sets forth the principal terms and conditions of your employment.\n1. Position and Reporting\nYou will join Acme Corporation as a Senior Software Engineer. Your duties will include, but not be\nlimited to: designing, coding, testing, and maintaining enterprise applications; collaborating with\ncross-functional teams; mentoring junior engineers; and ensuring compliance with internal security\nand data privacy standards. You will report directly to John Smith, Chief Technology Officer. This\nis a full-time, exempt position under California wage and hour law. Your primary work location will\nbe San Francisco, CA, but you may be required to travel up to 10% of your time.\n2. Start Date and Duration\nYour employment is expected to commence on April 24, 2023, contingent upon satisfaction of the\nconditions listed in Section 6. The offer will expire on April 15, 2023, unless you provide your\nsigned acceptance before that date.\n3. Compensation\nBase Salary: You will be paid an annual base salary of $150,000, payable in bi-weekly\ninstallments. Bonus: You will be eligible for a discretionary annual bonus targeted at 10% of your\nbase salary. Equity Grant: Subject to Board approval, you will receive a grant of 10,000 Restricted\nStock Units (RSUs), vesting over 4 years with a 1-year cliff.\n4. Benefits and Paid Time Off\nYou will be eligible for Company benefits as described in the Employee Handbook, including\nhealth, dental, vision, 401(k) with 4% match, 15 vacation days per year, 10 paid holidays, and sick\nleave in accordance with California Healthy Workplaces, Healthy Families Act.\n5. Confidentiality, IP, and Conflict of Interest\nYou will be required to sign the Confidential Information and Invention Assignment Agreement\n(CIIAA). Key obligations include: protecting proprietary information; assigning inventions to the\nCompany; and avoiding conflicts of interest. Failure to comply may result in disciplinary action or\ntermination.\n6. Contingencies\nThis offer is contingent upon: verification of your legal right to work in the U.S.; completion of a\nbackground check; execution of the Mutual Arbitration Agreement; and review of the Employee\nHandbook.\n7. Arbitration Agreement (California)\nYou agree to resolve any disputes arising out of your employment exclusively through binding\narbitration, pursuant to the Federal Arbitration Act and California Arbitration Act. This includes\nclaims for discrimination, harassment, wrongful termination, or breach of contract. You waive the\nright to pursue claims in court or before a jury, except as required by law.\n8. At-Will Employment\nYour employment is at-will. Either you or the Company may terminate at any time, with or without\ncause or notice.\n9. Governing Law\nThis offer and your employment shall be governed by the laws of the State of California.\n10. Entire Agreement\nThis letter, along with the CIIAA and Arbitration Agreement, contains the entire understanding\nbetween you and the Company and supersedes prior agreements.\nWe are excited about your contributions and look forward to welcoming you. Please indicate your\nacceptance of this offer by signing and returning this letter by April 15, 2023.\nSincerely,\nAcme Corporation\nBy: John Smith, CTO\nAcknowledgment and Acceptance\nI, Jane Doe, accept this offer of employment with Acme Corporation under the terms described\nabove.\nSigned: ____________________________\nName: Jane Doe\nDate: ____________________________'

# %%
#Ollama Extraction for PDF text
import ollama

prompt = f"Extract and summarize key details from this PDF:\n\n{pdf_text}"

response = ollama.chat(
    model="llama3",
    messages=[
        {"role": "system", "content": "You summarize and extract data from PDF text."},
        {"role": "user", "content": prompt}
    ]
)

print("Extracted Info from PDF:\n")
print(response['message']['content'])
# Out:
# Extracted Info from PDF:
#
# Here are the key details extracted and summarized from the PDF:
#
# **Position and Reporting**
#
# * Job title: Senior Software Engineer
# * Duties: designing, coding, testing, maintaining enterprise applications; mentoring junior engineers; ensuring compliance with internal security and data privacy standards
# * Supervisor: John Smith, Chief Technology Officer
# * Work location: San Francisco, CA (with occasional travel up to 10% of the time)
#
# **Start Date and Duration**
#
# * Expected start date: April 24, 2023 (contingent upon satisfaction of conditions listed in Section 6)
# * Offer expiration date: April 15, 2023
# * Job duration: At-will employment
#
# **Compensation**
#
# * Base salary: $150,000 per year, paid bi-weekly
# * Bonus: Discretionary annual bonus targeted at 10% of base salary
# * Equity grant: 10,000 Restricted Stock Units (RSUs), vesting over 4 years with a 1-year cliff (subject to Board approval)
#
# **Benefits and Paid Time Off**
#
# * Eligible for Company benefits as described in the Employee Handbook
# * Includes health, dental, vision, 401(k) with 4% match, 15 vacation days per year, 10 paid holidays, and sick leave
#
# **Confidentiality, IP, and Conflict of Interest**
#
# * Required to sign Confidential Information and Invention Assignment Agreement (CIIAA)
# * Obligations: protect proprietary information, assign inventions to the Company, avoid conflicts of interest
# * Failure to comply may result in disciplinary action or termination
#
# **Contingencies**
#
# * Offer contingent upon:
# 	+ Verification of legal right to work in the U.S.
# 	+ Completion of a background check
# 	+ Execution of the Mutual Arbitration Agreement
# 	+ Review of the Employee Handbook
#
# **Arbitration Agreement (California)**
#
# * Agrees to resolve disputes arising out of employment exclusively through binding arbitration, pursuant to Federal Arbitration Act and California Arbitration Act
# * Waives right to pursue claims in court or before a jury, except as required by law
#
# I hope this summary helps! Let me know if you have any further questions.

# %%
#Open AI API call to summarize and extract key details from the PDF text

prompt = f"Extract and summarize key details from this PDF:\n\n{pdf_text}"

response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You summarize and extract data from PDF text."},
        {"role": "user", "content": prompt}
    ]
)

print("Extracted Info from PDF:\n")
print(response.choices[0].message.content)
# Out:
# Extracted Info from PDF:
#
# Here are the key details from the Employment Offer Letter (California) to Jane Doe from Acme Corporation.
#
# Document and parties
# - Date of letter: April 1, 2023
# - Employer: Acme Corporation, 1234 Market Street, San Francisco, CA 94105
# - Recipient: Jane Doe, 567 Oak Avenue, San Jose, CA 95112
# - Private & Confidential
#
# Position and reporting
# - Title: Senior Software Engineer
# - Duties (illustrative): designing, coding, testing, and maintaining enterprise applications; collaborating with cross-functional teams; mentoring junior engineers; ensuring compliance with security and data privacy standards
# - Reports to: John Smith, Chief Technology Officer
# - Employment type: full-time, exempt
# - Primary work location: San Francisco, CA
# - Travel: up to 10% of time
#
# Start date and offer expiration
# - Start date: April 24, 2023 (contingent on conditions in Section 6)
# - Offer expiration: April 15, 2023 (signed acceptance required by then)
#
# Compensation
# - Base salary: $150,000 per year, paid bi-weekly
# - Bonus: discretionary annual bonus targeted at 10% of base salary
# - Equity: 10,000 Restricted Stock Units (RSUs), subject to Board approval; vesting over 4 years with a 1-year cliff
#
# Benefits and paid time off
# - Benefits: health, dental, vision; 401(k) with 4% match
# - PTO: 15 vacation days per year
# - Holidays: 10 paid holidays per year
# - Sick leave: per California Healthy Workplaces, Healthy Families Act
#
# Confidentiality, IP, and conflicts of interest
# - Agreement to sign: Confidential Information and Invention Assignment Agreement (CIIAA)
# - Key obligations: protect proprietary information; assign inventions to the Company; avoid conflicts of interest
# - Consequences of non-compliance: disciplinary action or termination
#
# Contingencies
# - Conditions to employment: verification of legal right to work in the U.S.; background check completion; execution of Mutual Arbitration Agreement; review of Employee Handbook
#
# Arbitration and dispute resolution
# - Disputes: resolved exclusively by binding arbitration
# - Legal basis: pursuant to the Federal Arbitration Act and California Arbitration Act
# - Scope: claims including discrimination, harassment, wrongful termination, or breach of contract
# - Waiver: waiver of right to sue in court or before a jury, except as required by law
#
# At-will employment and governing law
# - At-will: employment can be terminated by either party, at any time, with or without cause or notice
# - Governing law: State of California
#
# Entire agreement
# - This letter, plus the CIIAA and Arbitration Agreement, constitutes the entire agreement and supersedes prior agreements
#
# Acceptance
# - To accept: sign and return the letter by April 15, 2023
# - Signatures:
#   - From the Company: John Smith, CTO
#   - From the employee: Jane Doe (signature line provided)
#   - Date of acceptance: to be filled by Jane Doe
#
# Executive takeaway
# - This offer provides a $150k base salary, a 10% target annual bonus, and 10,000 RSUs (4-year vesting with 1-year cliff), with standard CA benefits and PTO.
# - Employment is contingent on eligibility to work in the U.S., background check, signing arbitration and handbook reviews, plus the CIIAA.
# - Employment is at-will and governed by California law, with disputes resolved via arbitration.

# %% [markdown]
# #### Extract Information from a DOCX (Word) File
# ###### Reads paragraphs and asks GPT-5-nano for key points.

# %%
docx_path = "data/Project_List.docx" 

def extract_text_from_docx(path):
    document = docx.Document(path)
    return "\n".join([p.text for p in document.paragraphs])

docx_text = extract_text_from_docx(docx_path)

print (f"Extracted DOCX Text (first 500 chars):\n{docx_text[:500]}\n")
prompt = f"Extract key points from this DOCX content:\n\n{docx_text[:8000]}"
# Out:
# Extracted DOCX Text (first 500 chars):
#
# Project 1
#
# Project: Real Estate Platform - eREP
# Company: Sansa Technology LLC, Milpitas, CA, USA
# Duration: From March 2017 – Current
# Role: Java EE Developer
# Description:
# eREP provides leading real estate and rental marketplace platform. eREP serves the full lifecycle of owning and living in a home: buying, selling, renting, financing, remodeling and more.
# Responsibilities:
# • Analyzed requirements and designed class diagrams, sequence diagrams using UML and
# prepared high level technical documen

# %%
#Open AI API call to summarize and extract key details from the DOCX text
response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You summarize and extract structured data from Word documents."},
        {"role": "user", "content": prompt}
    ]
)

print("Extracted Info from DOCX:\n")
print(response.choices[0].message.content)
# Out:
# Extracted Info from DOCX:
#
# Here are the key points organized by project.
#
# Project 1 – Real Estate Platform (eREP)
# - Company: Sansa Technology LLC, Milpitas, CA, USA
# - Duration: March 2017 – Current
# - Role: Java EE Developer
# - Description: eREP is a real estate and rental marketplace platform covering the full lifecycle of home ownership (buying, selling, renting, financing, remodeling, etc.).
# - Responsibilities:
#   - Analyzed requirements and designed class/sequence diagrams using UML; prepared high-level technical documents.
#   - Implemented Java and J2EE design patterns.
#   - Used Spring MVC with annotations and XML for Dependency Injection.
#   - Implemented persistence with Hibernate to interact with MySQL.
#   - Wrote SQL queries in the DAO layer.
#   - Developed REST web services using Spring, Hibernate, JAX-RS, and JAXB.
#   - Built UI with Spring view components, JSP, HTML, CSS, JavaScript, and AngularJS.
#   - Used Jenkins for CI/CD (build, test, deploy).
# - Environment / Tech Stack:
#   - Java 8, Java EE 7, Spring Framework 4.0, Spring MVC, Hibernate 4.3
#   - REST Web Services, JAX-RS, JAXB, JSP, HTML, CSS, JavaScript, AngularJS
#   - SQL, HQL, XML, UML, Log4J
#   - Apache Tomcat 7.0, MySQL, JUnit, Jenkins
#
# Project 2 – Online Advertising Platform (OAP)
# - Company: Sansa Technology LLC, Milpitas, CA, USA
# - Duration: March 2016 – Feb 2017
# - Role: Java EE Developer
# - Description: Sansa Listings Project is a classifieds site (like Craigslist) with categories such as Housing, Lessons, Community. Frontend uses JSP/HTML/CSS; Backend uses Servlet, Hibernate, Struts 2 (MVC), and Web Services. Deployed on Tomcat 8.x.
# - Responsibilities:
#   - Analyzed requirements and designed class/sequence diagrams using UML; prepared high-level technical documents.
#   - Implemented Java and J2EE design patterns.
#   - Used Spring MVC with annotations/XML for Dependency Injection.
#   - Implemented persistence with Hibernate for MySQL.
#   - Wrote SQL queries in the DAO layer.
#   - Developed REST web services using Spring, Hibernate, JAX-RS, and JAXB.
#   - Developed UI with Spring view components, JSP, HTML, CSS, JavaScript, and AngularJS.
#   - Used Jenkins for CI/CD (build, test, deploy).
# - Environment / Tech Stack:
#   - Java 8, Java EE 7, Spring Framework 4.0, Spring MVC, Hibernate 4.3
#   - REST Web Services, JAX-RS, JAXB, JSP, HTML, CSS, JavaScript, AngularJS
#   - SQL, HQL, XML, UML, Log4J
#   - Apache Tomcat 7.0, MySQL, JUnit, Jenkins
#
# Project 3 – Online Examination Portal (OEP)
# - Company: Sansa Technology LLC, Milpitas, CA, USA
# - Duration: March 2015 – Feb 2016
# - Role: Java EE Developer
# - Description: Online Examination Portal enabling online tests; instructors can create exams with multiple-choice, boolean, and free-text questions.
# - Responsibilities:
#   - Analyzed requirements and designed class/sequence diagrams using UML; prepared high-level technical documents.
#   - Implemented Java and J2EE design patterns.
#   - Used Spring MVC with annotations/XML for Dependency Injection.
#   - Implemented persistence with Hibernate to interact with MySQL.
#   - Wrote SQL queries in the DAO layer.
#   - Developed REST web services using Spring, Hibernate, JAX-RS, and JAXB.
#   - Developed UI with Spring view components, JSP, HTML, CSS, JavaScript, and AngularJS.
#   - Used Jenkins for CI/CD (build, test, deploy).
# - Environment / Tech Stack:
#   - Java 8, Java EE 7, Spring Framework 4.0, Spring MVC, Hibernate 4.3
#   - REST Web Services, JAX-RS, JAXB, JSP, HTML, CSS, JavaScript, AngularJS
#   - SQL, HQL, XML, UML, Log4J
#   - Apache Tomcat 7.0, MySQL, JUnit, Jenkins
#
# Cross-project highlights
# - Common patterns and responsibilities:
#   - Requirements analysis and UML-based design (class/sequence diagrams).
#   - Java/J2EE design patterns; Spring MVC with DI (annotation/XML).
#   - Hibernate-based persistence with MySQL; SQL in DAO layer.
#   - RESTful web services (Spring, Hibernate, JAX-RS/JAXB).
#   - UI with JSP/HTML/CSS/JavaScript and AngularJS.
#   - CI/CD with Jenkins; server runtime on Apache Tomcat.
# - Core tech stack appearing across projects:
#   - Java 8, Java EE 7, Spring Framework 4.0, Spring MVC
#   - Hibernate 4.3, REST Web Services, JAX-RS/JAXB
#   - JSP, HTML, CSS, JavaScript, AngularJS
#   - SQL/HQL, XML, UML
#   - Tomcat, MySQL, JUnit, Jenkins
#
# If you’d like, I can convert this into a JSON or CSV structured format for easy parsing.

# %%
#Ollama Extraction for DOCX text
response = ollama.chat (
    model="llama3",
    messages=[
        {"role": "system", "content": "You summarize and extract structured data from Word documents."},
        {"role": "user", "content": prompt}
    ]
)

print("Extracted Info from DOCX:\n")
print(response["message"]["content"])
# Out:
# Extracted Info from DOCX:
#
# Here are the key points extracted from the DOCX content:
#
# **Project 1: Real Estate Platform - eREP**
#
# * Duration: From March 2017 – Current
# * Role: Java EE Developer
# * Description: eREP provides a leading real estate and rental marketplace platform.
# * Responsibilities:
# 	+ Analyzed requirements, designed class diagrams and sequence diagrams using UML, and prepared high-level technical documents.
# 	+ Implemented Java and J2EE Design patterns.
# 	+ Utilized Spring MVC annotations and XML configuration for Dependency Injection.
# 	+ Implemented Persistence layer using Hibernate to interact with the MySQL database.
# 	+ Developed REST web services using spring, Hibernate, JAX-RS, and JAXB.
# 	+ Developed UI using spring view component, JSP, HTML, CSS, JavaScript, and AngularJS.
# * Environment: Java 8, Java EE 7, Spring Framework 4.0, Spring MVC, Hibernate 4.3, REST Web Services, JAXRS, JAXB, JSP, HTML, CSS, JavaScript, Angular JS, SQL, HQL, XML, UML, Log4J, Apache Tomcat 7.0, MySQL, JUnit, Log4j, Jenkins.
#
# **Project 2: Online Advertising Platform - OAP**
#
# * Duration: From March 2016 – Feb 2017
# * Role: Java EE Developer
# * Description: Sansa Listings Project is a classifieds website like Craigslist.
# * Responsibilities:
# 	+ Analyzed requirements, designed class diagrams and sequence diagrams using UML, and prepared high-level technical documents.
# 	+ Implemented Java and J2EE Design patterns.
# 	+ Utilized Spring MVC annotations and XML configuration for Dependency Injection.
# 	+ Implemented Persistence layer using Hibernate to interact with the MySQL database.
# 	+ Developed REST web services using spring, Hibernate, JAX-RS, and JAXB.
# 	+ Developed UI using spring view component, JSP, HTML, CSS, JavaScript, and AngularJS.
# * Environment: Java 8, Java EE 7, Spring Framework 4.0, Spring MVC, Hibernate 4.3, REST Web Services, JAXRS, JAXB, JSP, HTML, CSS, JavaScript, Angular JS, SQL, HQL, XML, UML, Log4J, Apache Tomcat 7.0, MySQL, JUnit, Log4j, Jenkins.
#
# **Project 3: Online Examination Portal - OEP**
#
# * Duration: From March 2015 – Feb 2016
# * Role: Java EE Developer
# * Description: Online examination Portal allows companies to conduct a test online to measure the knowledge of participants.
# * Responsibilities:
# 	+ Analyzed requirements, designed class diagrams and sequence diagrams using UML, and prepared high-level technical documents.
# 	+ Implemented Java and J2EE Design patterns.
# 	+ Utilized Spring MVC annotations and XML configuration for Dependency Injection.
# 	+ Implemented Persistence layer using Hibernate to interact with the MySQL database.
# 	+ Developed REST web services using spring, Hibernate, JAX-RS, and JAXB.
# 	+ Developed UI using spring view component, JSP, HTML, CSS, JavaScript, and AngularJS.
# * Environment: Java 8, Java EE 7, Spring Framework 4.0, Spring MVC, Hibernate 4.3, REST Web Services, JAXRS, JAXB, JSP, HTML, CSS, JavaScript, Angular JS, SQL, HQL, XML, UML, Log4J, Apache Tomcat 7.0, MySQL, JUnit, Log4j, Jenkins.
#
# Let me know if you need anything else!
