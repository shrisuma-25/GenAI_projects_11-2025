# %%
# %pip install openai python-dotenv

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv(override=True, dotenv_path="../.env")
my_api_key = os.getenv("OPENAI_API_KEY")

# %%
from openai import OpenAI
client = OpenAI(api_key=my_api_key)

def ask_question(prompt):
    print(f"User asked: {prompt}")
    response = client.chat.completions.create(
        model="gpt-5-nano",
        messages=[
            {"role": "system", "content": "You are a creative property listing assistant that generates a very cool property description based on the user input. Be creative!"},
            {"role": "user", "content": prompt}
        ]
    )
    print (response)
    return response.choices[0].message.content

# %%
user_prompt = input("Ask something: ")

response = ask_question(user_prompt)
print("\nOpenAI says:", response)
# Out:
# User asked: I am selling a property with 5 br, 3 baths in the heart of Fremont. Property is 3500sqft and close to best school district
# ChatCompletion(id='chatcmpl-CbahGBbHErApi45XAarNBlQXivM0X', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Step into modern family living in Fremont’s most desirable pocket. This spacious 5-bedroom, 3-bath home delivers 3,500 square feet of thoughtfully designed space—built for growth, entertaining, and everyday comfort. Meticulously laid out with flexible living areas, sunlit rooms, and rooms you can customize for office, study, or play, this is a home that adapts with your lifestyle.\n\nNestled in the heart of Fremont, you’ll enjoy the perks of a prime location and one of the area’s top school districts. Close to excellent schools and surrounded by conveniences, this is the kind of pedigree you can see in the daily flow of life—easy commutes, neighborhood parks, shops, and dining within reach.\n\nKey details\n- 5 bedrooms, 3 baths\n- 3,500 square feet of living space\n- Central Fremont location in a top-rated school district\n- Flexible, bright layout designed for work, family, and entertaining\n- Built for comfort and long-term livability\n\nIf you’d like, I can tailor this with any standout features you want emphasized (recent upgrades, outdoor space, garage details) or craft a few micro-versions for different channels (MLS, social, brochure). Ready to list, or want a punchy opening line to test?', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1763075234, model='gpt-5-nano-2025-08-07', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=2320, prompt_tokens=65, total_tokens=2385, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=2048, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
#
# OpenAI says: Step into modern family living in Fremont’s most desirable pocket. This spacious 5-bedroom, 3-bath home delivers 3,500 square feet of thoughtfully designed space—built for growth, entertaining, and everyday comfort. Meticulously laid out with flexible living areas, sunlit rooms, and rooms you can customize for office, study, or play, this is a home that adapts with your lifestyle.
#
# Nestled in the heart of Fremont, you’ll enjoy the perks of a prime location and one of the area’s top school districts. Close to excellent schools and surrounded by conveniences, this is the kind of pedigree you can see in the daily flow of life—easy commutes, neighborhood parks, shops, and dining within reach.
#
# Key details
# - 5 bedrooms, 3 baths
# - 3,500 square feet of living space
# - Central Fremont location in a top-rated school district
# - Flexible, bright layout designed for work, family, and entertaining
# - Built for comfort and long-term livability
#
# If you’d like, I can tailor this with any standout features you want emphasized (recent upgrades, outdoor space, garage details) or craft a few micro-versions for different channels (MLS, social, brochure). Ready to list, or want a punchy opening line to test?
