# %% [markdown]
# #### Print Statments

# %%
print ("Hello AI World")
# Out:
# Hello AI World

# %%
name= "Alice"
score = 95.5
print (f" {name} scored {score} in the exam.")
# Out:
#  Alice scored 95.5 in the exam.

# %%
print ("Name: ", name, ", Score: ", score)
# Out:
# Name:  Alice , Score:  95.5

# %%
name = input("What is your name? ")
print("Hello, " + name + "! Welcome to AI training.")
print (f"Hello, {name} ")
# Out:
# Hello, Olivia! Welcome to AI training.
# Hello, Olivia

# %%
age_str = input("Enter your age: ")
age = int(age_str)
print("Hello", age)
print(f"Hello, {age}")
# Out:
# Hello 35
# Hello, 35

# %%
print(type(age))
print(float(age))
print(str(age))
# Out:
# <class 'int'>
# 35.0
# 35

# %% [markdown]
# #### Control Flow

# %%
x = 10
if x > 5:
    print("x is greater than 5")
# Out:
# x is greater than 5

# %%
x =3
if x > 5:
    print("x is greater than 5")
else:
    print("x is not greater than 5 ")
# Out:
# x is not greater than 5

# %%
score = 85
if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >=70:
    print("Grade: C")
else:
    print("Grade: F")
# Out:
# Grade: B

# %%
# While condition syntax
i=1
while i <=5:
    print("Iteration:", i)
    i +=1
# Out:
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5

# %%
while True:
    print("This will run forever unless you break it !")
    break
# Out:
# This will run forever unless you break it !

# %%
import time
while True:
    # Ask user a question
    user_prompt = input("Ask Something: ")
    if (user_prompt.lower() != 'quit'):
        # Get and Print the response
        response = "FAKE RESPONSE FROM OPENAI FOR: " + user_prompt
        print("\nOpenAI says:", response)

        #add delay of 3 seconds
        time.sleep(3)
    else:
        print("Exiting the loop. Goodbye!")
        break
# Out:
# OpenAI says: FAKE RESPONSE FROM OPENAI FOR: where is canada
#
# OpenAI says: FAKE RESPONSE FROM OPENAI FOR:
# Exiting the loop. Goodbye!
