# %% [markdown]
# #### Milvus Vector DB for RAG

# %% [markdown]
# ##### Create collection of legal docs

# %%
# %pip install pymilvus
# %pip install milvus-cli
# Out:
# Requirement already satisfied: pymilvus in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (2.6.4)
# Requirement already satisfied: setuptools>69 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pymilvus) (80.9.0)
# Requirement already satisfied: grpcio!=1.68.0,!=1.68.1,!=1.69.0,!=1.70.0,!=1.70.1,!=1.71.0,!=1.72.1,!=1.73.0,>=1.66.2 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pymilvus) (1.76.0)
# Requirement already satisfied: orjson>=3.10.15 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pymilvus) (3.11.4)
# Requirement already satisfied: protobuf>=5.27.2 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pymilvus) (6.33.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pymilvus) (1.2.1)
# Requirement already satisfied: pandas>=1.2.4 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pymilvus) (2.3.3)
# Requirement already satisfied: typing-extensions~=4.12 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from grpcio!=1.68.0,!=1.68.1,!=1.69.0,!=1.70.0,!=1.70.1,!=1.71.0,!=1.72.1,!=1.73.0,>=1.66.2->pymilvus) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pandas>=1.2.4->pymilvus) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pandas>=1.2.4->pymilvus) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pandas>=1.2.4->pymilvus) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pandas>=1.2.4->pymilvus) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting milvus-cli
#   Downloading milvus_cli-1.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting Click==8.0.1 (from milvus-cli)
#   Downloading click-8.0.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pymilvus>=2.5.0 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from milvus-cli) (2.6.4)
# Collecting tabulate==0.8.9 (from milvus-cli)
#   Downloading tabulate-0.8.9-py3-none-any.whl.metadata (23 kB)
# Collecting requests==2.31.0 (from milvus-cli)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from requests==2.31.0->milvus-cli) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from requests==2.31.0->milvus-cli) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from requests==2.31.0->milvus-cli) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from requests==2.31.0->milvus-cli) (2025.11.12)
# Requirement already satisfied: setuptools>69 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pymilvus>=2.5.0->milvus-cli) (80.9.0)
# Requirement already satisfied: grpcio!=1.68.0,!=1.68.1,!=1.69.0,!=1.70.0,!=1.70.1,!=1.71.0,!=1.72.1,!=1.73.0,>=1.66.2 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pymilvus>=2.5.0->milvus-cli) (1.76.0)
# Requirement already satisfied: orjson>=3.10.15 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pymilvus>=2.5.0->milvus-cli) (3.11.4)
# Requirement already satisfied: protobuf>=5.27.2 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pymilvus>=2.5.0->milvus-cli) (6.33.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pymilvus>=2.5.0->milvus-cli) (1.2.1)
# Requirement already satisfied: pandas>=1.2.4 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pymilvus>=2.5.0->milvus-cli) (2.3.3)
# Requirement already satisfied: typing-extensions~=4.12 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from grpcio!=1.68.0,!=1.68.1,!=1.69.0,!=1.70.0,!=1.70.1,!=1.71.0,!=1.72.1,!=1.73.0,>=1.66.2->pymilvus>=2.5.0->milvus-cli) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pandas>=1.2.4->pymilvus>=2.5.0->milvus-cli) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pandas>=1.2.4->pymilvus>=2.5.0->milvus-cli) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pandas>=1.2.4->pymilvus>=2.5.0->milvus-cli) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from pandas>=1.2.4->pymilvus>=2.5.0->milvus-cli) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/suma/Training/11-2025-AItraining/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus>=2.5.0->milvus-cli) (1.17.0)
# Downloading milvus_cli-1.0.2-py3-none-any.whl (54 kB)
# Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
# Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Installing collected packages: tabulate, requests, Click, milvus-cli
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.5
#     Uninstalling requests-2.32.5:
#       Successfully uninstalled requests-2.32.5
#   Attempting uninstall: Click
#     Found existing installation: click 8.3.1
#     Uninstalling click-8.3.1:
#       Successfully uninstalled click-8.3.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [milvus-cli]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 4.4.1 requires requests>=2.32.2, but you have requests 2.31.0 which is incompatible.
# langchain-community 0.4.1 requires requests<3.0.0,>=2.32.5, but you have requests 2.31.0 which is incompatible.
# instructor 1.13.0 requires requests<3.0.0,>=2.32.3, but you have requests 2.31.0 which is incompatible.
# Successfully installed Click-8.0.1 milvus-cli-1.0.2 requests-2.31.0 tabulate-0.8.9
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymilvus import connections
from pymilvus import connections

# If using Docker standalone Milvus
connections.connect("default", host="127.0.0.1", port="19530")

# %%
from pymilvus import db

# 1. Create a new database
# db.create_database("rag_db")

# 2. Switch to that database
db.using_database("rag_db")
